# %%
result = []
books = dict.fromkeys(list("abcdefghijklmnopqrstuvwz"), 0)
#print(books)

#単語を入力して格納する。
while True:
    word = input("英単語を入力してください：")
    if word == "":
        break
    result.append(word)

#各単語を順番に取り出してbooksから検索してカウントする。
for word in result:
    for w in word: 
        if w in books:
            books[w] += 1

#表示させる。
print(f"入力した英単語：{sorted(result)}")
for key, count in books.items():
    if count > 0:
        print(f"{key}が{count}個ありました")
# Out:
# 入力した英単語：['bear', 'cat', 'dog', 'giraffe', 'horse', 'kangaroo']
# aが5個ありました
# bが1個ありました
# cが1個ありました
# dが1個ありました
# eが3個ありました
# fが2個ありました
# gが3個ありました
# hが1個ありました
# iが1個ありました
# kが1個ありました
# nが1個ありました
# oが4個ありました
# rが4個ありました
# sが1個ありました
# tが1個ありました
