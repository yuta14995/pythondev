# %%
#@title 九九のリストを作成する
nine = [[i * j for j in range(1, 10)] for i in range(1, 10)]
"""
for i in range(1, 10):
    row = []  # 1行分の箱
    for j in range(1, 10):
        row.append(i * j)
    nine.append(row)  # 各行をnineに追加する
"""

for row in nine:
    print(row)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# [2, 4, 6, 8, 10, 12, 14, 16, 18]
# [3, 6, 9, 12, 15, 18, 21, 24, 27]
# [4, 8, 12, 16, 20, 24, 28, 32, 36]
# [5, 10, 15, 20, 25, 30, 35, 40, 45]
# [6, 12, 18, 24, 30, 36, 42, 48, 54]
# [7, 14, 21, 28, 35, 42, 49, 56, 63]
# [8, 16, 24, 32, 40, 48, 56, 64, 72]
# [9, 18, 27, 36, 45, 54, 63, 72, 81]

# %%
#@title 九九の表を表示する
for row in nine:
    for num in row:
        print(f"{num:3d}", end="")  # 3桁幅で整形して改行せず出力
    print("")  # 各行の出力後に改行
# Out:
#   1  2  3  4  5  6  7  8  9
#   2  4  6  8 10 12 14 16 18
#   3  6  9 12 15 18 21 24 27
#   4  8 12 16 20 24 28 32 36
#   5 10 15 20 25 30 35 40 45
#   6 12 18 24 30 36 42 48 54
#   7 14 21 28 35 42 49 56 63
#   8 16 24 32 40 48 56 64 72
#   9 18 27 36 45 54 63 72 81
